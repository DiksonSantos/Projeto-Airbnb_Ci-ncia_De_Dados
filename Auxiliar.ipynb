# %%
from IPython.display import Image

# %%
# Compara as colunas hos... == host...  | Value_Counts -> Total de Trues e Falses

#print((base_airbnb['host_listings_count']==base_airbnb['host_total_listings_count']).value_counts())

# ExistemPoucos valores falsos -> Eles podem ser ignorados. 
# Porém a coluna 'host_total_listings_count' foi excluida. (Pois as duas são raticamente iguais)

# %%
# Quantidade de celulas vazias na coluna 'square_feet' :
#print(base_airbnb['square_feet'].isnull().sum())

# Muitas celulas vazias -> Coluna excluida.

# %%
# print('COntagem & Soma de NULOS:')
# print('CONTAGEM De Valoresw Vazios:',base_airbnb['square_feet'].isnull().count())
# print('SOMA De Valoresw Vazios:',base_airbnb['square_feet'].isnull().sum())

"""É sempre melhor excluir Colunas com cerca (ou Mais de 50%)
de valores nulos/vazios"""

# %%
Image(filename='Analise exploratoria_Texto_.png',width=1600, height=800)
